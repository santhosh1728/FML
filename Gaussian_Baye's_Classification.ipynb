# %% [markdown]
# <a href="https://colab.research.google.com/github/santhosh1728/FML/blob/main/Gaussian_Baye's_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.drop(labels='Id',axis=1,inplace=True)

# %%
columns = df.columns.tolist()

# %%
columns
# Out:
# ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']

# %%
Classes = (df[
  'Species'].unique()
)

# %%
Classes
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
result = df.loc[df['Species'] == Classes[0]], columns[0]

# %%
def get_pdf_par(attribute,Classes):
  result = (df.loc[df['Species'] == Classes])[attribute]
  mean = np.mean(result)
  var = np.std(result)**2
  return mean,var

# %%
def get_likelihood(value,mean,var):
  r = 1/(np.sqrt(2*np.pi*var))*np.exp(-(value-mean)**2/(2*var))
  return r

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
T = {'SepalLengthCm':5,'SepalWidthCm':2,
     'PetalLengthCm':3.5,'PetalWidthCm':1}

# %%
T.keys()
# Out:
# dict_keys(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'])

# %%
S = []
for j in Classes:
  L = 0
  for i in T.keys():
    m,v = get_pdf_par(i,j)
    likelihood = np.log(get_likelihood(T[i],m,v))
    L = likelihood
  S.append(L)

# %%
ind_1 = np.where(S == np.max(S))
predicted_class = Classes[ind_1[0][0]]

# %%
print(predicted_class)
# Out:
# Iris-versicolor
